# %%
Knn_Score=0.8205128205128205
Svm_Score=0.8974358974358975
Log_Score=0.8205128205128205
XG_Score=0.9487179487179487

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plot =[Knn_Score,Svm_Score,Log_Score,XG_Score]
names=['Knn','Svm','Log','XG']
tick_label=['KNN','SVM','LOGISTIC','XG-BOOST']
plt.bar(names,plot,tick_label=tick_label,width=0.5,color=['royalblue','hotpink','orange','limegreen'])
plt.xlabel('Algorithms')
plt.ylabel('Accuracies')
plt.title('Performance of Algorithms')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
